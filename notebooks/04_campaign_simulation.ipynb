# %% [markdown]
# # 04 - Campaign Simulation
#
# Scenario analysis for campaign budget, conversion rate, discount and ROI.

# %%
import sys
from pathlib import Path

root = Path.cwd().parents[0]
sys.path.insert(0, str(root / 'backend'))

from app.services.campaign_simulator_service import simulate_campaign

simulate_campaign(
    segment='VIP Customers',
    campaign_type='email',
    budget=1000,
    discount_pct=10,
    expected_conversion_rate=5,
)
